# %%
import camelot

# %%
import pandas

# %%
import seaborn

# %% [markdown]
# ## Extract 2 tables from PDF by specify what pages contains tables

# %%
input_PDF = camelot.read_pdf("DataTables-example.pdf", flavor = "stream", pages = "1,2")

# %%
input_PDF[0].df
# Out:
#                      0                              1              2    3  \
# 0                 Name                       Position         Office  Age
# 1           Airi Satou                     Accountant          Tokyo   33
# 2       Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 3           Ashton Cox        Junior Technical Author  San Francisco   66
# 4        Bradley Greer              Software Engineer         London   41
# 5       Brenden Wagner              Software Engineer  San Francisco   28
# 6   Brielle Williamson         Integration Specialist       New York   61
# 7           Bruno Nash              Software Engineer         London   38
# 8         Caesar Vance              Pre-Sales Support       New York   21
# 9         Cara Stevens                Sales Assistant       New York   46
# 10        Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 11     Charde Marshall              Regional Director  San Francisco   36
# ...

# %%
input_PDF[1].df
# Out:
#                       0                              1              2    3  \
# 0                  Name                       Position         Office  Age
# 1      Jackson Bradshaw                       Director       New York   65
# 2           Jena Gaines                 Office Manager         London   30
# 3      Jenette Caldwell               Development Lead       New York   30
# 4       Jennifer Acosta    Junior Javascript Developer      Edinburgh   43
# 5        Jennifer Chang              Regional Director      Singapore   28
# 6       Jonas Alexander                      Developer  San Francisco   30
# 7            Lael Greer          Systems Administrator         London   21
# 8        Martena Mccray             Post-Sales support      Edinburgh   46
# 9         Michael Bruce           Javascript Developer      Singapore   29
# 10        Michael Silva             Marketing Designer         London   66
# ...

# %% [markdown]
# ## Parse CSV-file

# %%
input_csv = pandas.read_csv("vgchartz-2024.csv")

# %%
input_csv
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# ...

# %% [markdown]
# ## Visualize data with bar chart

# %%
seaborn.barplot(x = "console", y = "critic_score", data = input_csv)
# Out:
# <Axes: xlabel='console', ylabel='critic_score'>
